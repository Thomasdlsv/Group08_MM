# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_40k = pd.DataFrame()
df_40k['angles'] = [0.0000, 2.0000, 4.0000, 6.0000, 8.0000, 10.0000, 12.0000, 14.0000, 16.0000, 18.0000, 20.0000, 22.0000, 24.0000, 26.0000, 30.0000, 40.0000, 50.0000, 60.0000, 70.0000, 80.0000, 90.0000, 100.0000, 110.0000, 120.0000, 130.0000, 140.0000, 150.0000, 160.0000, 170.0000, 180.0000]

df_40k['CL'] = [0.0000, 0.2200, 0.4464, 0.6115, -0.0615, 0.0344, 0.1406, 0.2484, 0.3563, 0.4644, 0.5708, 0.6755, 0.7809, 0.8873, 0.9150, 1.0750, 1.0400, 0.8750, 0.6500, 0.3700, 0.0700, -0.2200, -0.5100, -0.7350, -0.9100, -0.9450, -0.8500, -0.6600, -0.8500, 0.0000]

df_40k['CD'] = [0.0175, 0.0181, 0.0199, 0.0232, 0.0720, 0.1010, 0.1340, 0.1710, 0.2100, 0.2520, 0.2970, 0.3440, 0.3940, 0.4460, 0.5700, 0.9200, 1.2150, 1.4700, 1.6650, 1.7800, 1.8000, 1.7500, 1.6350, 1.4650, 1.2250, 0.9250, 0.5750, 0.3200, 0.1400, 0.0250]

df_80k = pd.DataFrame()
df_80k['angles'] = [0.0000, 2.0000, 4.0000, 6.0000, 8.0000, 10.0000, 12.0000, 14.0000, 16.0000, 18.0000, 20.0000, 22.0000, 24.0000, 26.0000, 30.0000, 40.0000, 50.0000, 60.0000, 70.0000, 80.0000, 90.0000, 100.0000, 110.0000, 120.0000, 130.0000, 140.0000, 150.0000, 160.0000, 170.0000, 180.0000]

df_80k['CL'] = [0.0000, 0.2200, 0.4400, 0.6384, 0.6930, 0.0413, 0.1430, 0.2504, 0.3582, 0.4689, 0.5770, 0.6839, 0.7902, 0.8963, 0.9150, 1.0750, 1.0400, 0.8750, 0.6500, 0.3700, 0.0700, -0.2200, -0.5100, -0.7350, -0.9100, -0.9450, -0.8500, -0.6600, -0.8500, 0.0000]

df_80k['CD'] = [0.0337, 0.0138, 0.0155, 0.0189, 0.0222, 0.0600, 0.1340, 0.1710, 0.2100, 0.2520, 0.2970, 0.3440, 0.3940, 0.4460, 0.5700, 0.9200, 1.2150, 1.4700, 1.6650, 1.7800, 1.8000, 1.7500, 1.6350, 1.4650, 1.2250, 0.9250, 0.5750, 0.3200, 0.1400, 0.0250]

df_160k = pd.DataFrame()
df_160k['angles'] = [0.0000, 2.0000, 4.0000, 6.0000, 8.0000, 10.0000, 12.0000, 14.0000, 16.0000, 18.0000, 20.0000, 22.0000, 24.0000, 26.0000, 30.0000, 40.0000, 50.0000, 60.0000, 70.0000, 80.0000, 90.0000, 100.0000, 110.0000, 120.0000, 130.0000, 140.0000, 150.0000, 160.0000, 170.0000, 180.0000]

df_160k['CL'] = [0.0000, 0.2200, 0.4400, 0.6600, 0.8274, 0.1325, 0.1533, 0.2546, 0.3620, 0.4768, 0.5870, 0.6956, 0.8034, 0.9109, 0.9150, 1.0750, 1.0400, 0.8750, 0.6500, 0.3700, 0.0700, -0.2200, -0.5100, -0.7350, -0.9100, -0.9450, -0.8500, -0.6600, -0.8500, 0.0000]

df_160k['CD'] = [0.0103, 0.0108, 0.0124, 0.0152, 0.0185, 0.0188, 0.1340, 0.1710, 0.2100, 0.2520, 0.2970, 0.3440, 0.3940, 0.4460, 0.5700, 0.9200, 1.2150, 1.4700, 1.6650, 1.7800, 1.8000, 1.7500, 1.6350, 1.4650, 1.2250, 0.9250, 0.5750, 0.3200, 0.1400, 0.0250]

df_360k = pd.DataFrame()
df_360k['angles'] = [0.0000, 2.0000, 4.0000, 6.0000, 8.0000, 10.0000, 12.0000, 14.0000, 16.0000, 18.0000, 20.0000, 22.0000, 24.0000, 26.0000, 30.0000, 40.0000, 50.0000, 60.0000, 70.0000, 80.0000, 90.0000, 100.0000, 110.0000, 120.0000, 130.0000, 140.0000, 150.0000, 160.0000, 170.0000, 180.0000]

df_360k['CL'] = [0.0000, 0.2200, 0.4400, 0.6600, 0.8542, 0.9811, 0.4832, 0.2893, 0.3792, 0.5047, 0.6120, 0.7179, 0.8246, 0.9313, 0.9150, 1.0750, 1.0400, 0.8750, 0.6500, 0.3100, 0.0700, -0.2200, -0.5100, -0.7350, -0.9100, -0.9450, -0.8500, -0.6600, -0.8500, 0.0000]

df_360k['CD'] = [0.0079, 0.0084, 0.0098, 0.0125, 0.0153, 0.0184, 0.0217, 0.1060, 0.2100, 0.2520, 0.2970, 0.3440, 0.3940, 0.4460, 0.5700, 0.9200, 1.2150, 1.4700, 1.6650, 1.7800, 1.8000, 1.7500, 1.6350, 1.4650, 1.2250, 0.9250, 0.5750, 0.3200, 0.1400, 0.0250]

# %%
p_cl_40 = np.polyfit(df_40k['angles'], df_40k['CL'], 12)
print(p_cl_40)

plt.plot(df_40k['angles'], df_40k['CL'], 'o')
plt.plot(df_40k['angles'], np.polyval(p_cl_40, df_40k['angles']))
plt.show()
# Out:
# [-5.24355321e-22  5.87755779e-19 -2.89008488e-16  8.19388682e-14
#  -1.48055281e-11  1.77848682e-09 -1.43694217e-07  7.71858604e-06
#  -2.65548530e-04  5.41984406e-03 -5.65701593e-02  2.41847930e-01
#   6.87196997e-03]

# %%
p_cd_40 = np.polyfit(df_40k['angles'], df_40k['CD'], 8)
print(p_cd_40)

plt.plot(df_40k['angles'], df_40k['CD'], 'o')
plt.plot(df_40k['angles'], np.polyval(p_cd_40, df_40k['angles']))
plt.show()
# Out:
# [-4.17039479e-16  3.00388984e-13 -8.72769465e-11  1.30390142e-08
#  -1.02818335e-06  3.48066557e-05  1.18292878e-05  6.67374805e-03
#   3.33465638e-03]

# %%
p_cl_80 = np.polyfit(df_80k['angles'], df_80k['CL'], 12)
print(p_cl_80)

plt.plot(df_80k['angles'], df_80k['CL'], 'o')
plt.plot(df_80k['angles'], np.polyval(p_cl_80, df_80k['angles']))
plt.show()
# Out:
# [-4.20379520e-22  4.80886259e-19 -2.41493061e-16  7.00096347e-14
#  -1.29583965e-11  1.59870586e-09 -1.33157745e-07  7.41387540e-06
#  -2.66640605e-04  5.77505996e-03 -6.60150348e-02  3.25181943e-01
#  -6.02958100e-02]

# %%
p_cd_80 = np.polyfit(df_80k['angles'], df_80k['CD'], 8)
print(p_cd_80)

plt.plot(df_80k['angles'], df_80k['CD'], 'o')
plt.plot(df_80k['angles'], np.polyval(p_cd_80, df_80k['angles']))
plt.show()
# Out:
# [-2.48325748e-16  1.73205705e-13 -4.79259540e-11  6.61031079e-09
#  -4.35005372e-07  4.25472367e-06  8.15894174e-04 -1.80594638e-03
#   1.54637923e-02]

# %%
p_cl_160 = np.polyfit(df_160k['angles'], df_160k['CL'], 12)
print(p_cl_160)

plt.plot(df_160k['angles'], df_160k['CL'], 'o')
plt.plot(df_160k['angles'], np.polyval(p_cl_160, df_160k['angles']))
plt.show()
# Out:
# [-3.80538880e-22  4.39074107e-19 -2.22386892e-16  6.50298778e-14
#  -1.21444459e-11  1.51245183e-09 -1.27263345e-07  7.16670805e-06
#  -2.61185279e-04  5.75117150e-03 -6.73014971e-02  3.43470555e-01
#  -7.70536143e-02]

# %%
p_cd_160 = np.polyfit(df_160k['angles'], df_160k['CD'], 10)
print(p_cd_160)

plt.plot(df_160k['angles'], df_160k['CD'], 'o')
plt.plot(df_160k['angles'], np.polyval(p_cd_160, df_160k['angles']))
plt.show()
# Out:
# [ 4.08490212e-20 -4.52956124e-17  2.06018993e-14 -5.04962787e-12
#   7.32358403e-10 -6.47921818e-08  3.50863157e-06 -1.19909660e-04
#   2.78592651e-03 -1.36273675e-02  1.71234760e-02]

# %%
p_cl_360 = np.polyfit(df_360k['angles'], df_360k['CL'], 12)
print(p_cl_360)

plt.plot(df_360k['angles'], df_360k['CL'], 'o')
plt.plot(df_360k['angles'], np.polyval(p_cl_360, df_360k['angles']))
plt.show()
# Out:
# [ 3.19357350e-23 -7.67865605e-21 -1.03194204e-17  7.09734778e-15
#  -2.09168670e-12  3.59077274e-10 -3.90391301e-08  2.74425949e-06
#  -1.22642094e-04  3.29473560e-03 -4.77440243e-02  3.18993255e-01
#  -1.06475061e-01]

# %%
p_cd_360 = np.polyfit(df_360k['angles'], df_360k['CD'], 10)
print(p_cd_360)

plt.plot(df_360k['angles'], df_360k['CD'], 'o')
plt.plot(df_360k['angles'], np.polyval(p_cd_360, df_360k['angles']))
plt.show()
# Out:
# [-3.97292972e-20  2.62846975e-17 -6.28238638e-15  4.91922989e-13
#   5.27555355e-11 -1.47357095e-08  1.40642592e-06 -7.75494863e-05
#   2.63598683e-03 -1.80322885e-02  2.39458963e-02]

# %%
# plot both CL 
plt.plot(df_40k['angles'], df_40k['CL'], '-')
plt.plot(df_80k['angles'], df_80k['CL'], '-')
plt.plot(df_160k['angles'], df_160k['CL'], '-')
plt.plot(df_360k['angles'], df_360k['CL'], '-')

# plot both CD
plt.plot(df_40k['angles'], df_40k['CD'], '-')
plt.plot(df_80k['angles'], df_80k['CD'], '-')
plt.plot(df_160k['angles'], df_160k['CD'], '-')
plt.plot(df_360k['angles'], df_360k['CD'], '-')

# %%
# Plot both polynomials
plt.plot(df_40k['angles'], np.polyval(p_cl_40, df_40k['angles']), '-')
plt.plot(df_80k['angles'], np.polyval(p_cl_80, df_80k['angles']), '-')
plt.plot(df_160k['angles'], np.polyval(p_cl_160, df_160k['angles']), '-')
plt.plot(df_360k['angles'], np.polyval(p_cl_360, df_360k['angles']), '-')

plt.plot(df_40k['angles'], np.polyval(p_cd_40, df_40k['angles']), '-')
plt.plot(df_80k['angles'], np.polyval(p_cd_80, df_80k['angles']), '-')
plt.plot(df_160k['angles'], np.polyval(p_cd_160, df_160k['angles']), '-')
plt.plot(df_360k['angles'], np.polyval(p_cd_360, df_360k['angles']), '-')


plt.legend(['CL 40k', 'CL 80k', 'CL 160k', 'CL 360k', 'CD 40k', 'CD 80k', 'CD 160k', 'CD 360k'])
plt.title('Polynomial fits for CL and CD on different Reynolds numbers')
plt.xlabel('Angles')
plt.ylabel('Values of Coefficients')
plt.savefig('polynomial_fits_for_all_parameters.png')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
def cd_custom(x):
    result = (- 2.34883452212131e-20 * x**10 
            + 1.16915339371553e-17  * x**9
            - 7.19105243730552e-16  * x**8
            - 6.78303608765851e-13  * x**7
            + 2.00518143371719e-10  * x**6
            - 2.61271931318120e-08  * x**5
            + 1.92548190311079e-06  * x**4
            - 9.01804243068557e-05  * x**3
            + 0.00275939330472374   * x**2
            - 0.0180052597286692    * x**1
            + 0.0230541325838875)
    return result

# %%
def cl_custom(x):
    result = (- 7.11145860926042e-19  * x**10
            + 7.29835098673025e-16  * x**9
            - 3.17294516756617e-13  * x**8
            + 7.63300503284026e-11  * x**7
            - 1.11225338175080e-08  * x**6
            + 1.00853574891538e-06  * x**5
            - 5.61414835267720e-05  * x**4
            + 0.00181651020401031   * x**3
            - 0.0308244844086802    * x**2
            + 0.241539695258776     * x**1
            - 0.0455606772480888)
    return result
